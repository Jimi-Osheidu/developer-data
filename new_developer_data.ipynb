# %%
import pandas as pd

# %%
df=pd.read_csv('Documents/survey_results_public.csv') #Loading the dataset

# %%
df.head() # To quickly test if the imported data is correct
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# ...

# %%
schema_df = pd.read_csv('Documents/survey_results_schema.csv') #To load schema data and get sense of what the questions are

# %%
schema_df.head()
# Out:
#       qid       qname                                           question  \
# 0   QID16          S0  <div><span style="font-size:19px;"><strong>Hel...
# 1   QID12    MetaInfo                                  Browser Meta Info
# 2    QID1          S1  <span style="font-size:22px; font-family: aria...
# 3    QID2  MainBranch  Which of the following options best describes ...
# 4  QID296  Employment  Which of the following best describes your cur...
#
#   force_resp  type selector
# 0      False    DB       TB
# 1      False  Meta  Browser
# 2      False    DB       TB
# 3       True    MC     SAVR
# 4      False    MC     MAVR

# %%
df.shape #Since I planned to drop some Columns, shape shows me how many rows and columns I have so I can tell what changes have happened.
# Out:
# (73268, 79)

# %%
schema_df.shape
# Out:
# (79, 6)

# %%
schema_df
# Out:
#        qid        qname                                           question  \
# 0    QID16           S0  <div><span style="font-size:19px;"><strong>Hel...
# 1    QID12     MetaInfo                                  Browser Meta Info
# 2     QID1           S1  <span style="font-size:22px; font-family: aria...
# 3     QID2   MainBranch  Which of the following options best describes ...
# 4   QID296   Employment  Which of the following best describes your cur...
# ..     ...          ...                                                ...
# 74  QID290  Frequency_2  Interacting with people outside of your immedi...
# 75  QID290  Frequency_3  Encountering knowledge silos (where one indivi...
# 76  QID294  TrueFalse_1  Are you involved in supporting new hires durin...
# 77  QID294  TrueFalse_2  Do you use learning resources provided by your...
# 78  QID294  TrueFalse_3  Does your employer give you time to learn new ...
#
#    force_resp  type selector
# 0       False    DB       TB
# ...

# %%
pd.set_option('display.max_columns', 79) #disabled truncation of rows, so I could see all the columns in the dataset

# %%
schema_df_key = pd.DataFrame(schema_df)

# %%
schema_df_key.loc[[76], ['qname', 'question']]
# Out:
#           qname                                           question
# 76  TrueFalse_1  Are you involved in supporting new hires durin...

# %%
pd.set_option('display.max_colwidth', None)

# %%
schema_df.set_index('qname', inplace = True)

# %%
schema_df.index
# Out:
# Index(['S0', 'MetaInfo', 'S1', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'S2', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'S3', 'Language', 'Database', 'Platform',
#        'Webframe', 'MiscTech', 'ToolsTech', 'NEWCollabTools', 'OpSys',
#        'VersionControlSystem', 'VCInteraction', 'VCHosting',
#        'OfficeStackAsync', 'OfficeStackSync', 'Blockchain', 'S4', 'NEWSOSites',
#        'SOVisitFreq', 'SOAccount', 'SOPartFreq', 'SOComm', 'S5', 'Age',
#        'Gender', 'Trans', 'Sexuality', 'Ethnicity', 'Accessibility',
#        'MentalHealth', 'S6', 'TBranch', 'ICorPM', 'WorkExp', 'Knowledge',
#        'Frequency', 'TimeSearching', 'TimeAnswering', 'Onboarding',
#        'ProfessionalTech', 'SOTeamsUsage', 'TrueFalse', 'S7', 'SurveyLength',
# ...

# %%
schema_df.loc['Age']
# Out:
# qid                      QID127
# question      What is your age?
# force_resp                False
# type                         MC
# selector                   MAVR
# Name: Age, dtype: object

# %%
schema_df.loc[ 'CompTotal', 'question']
# Out:
# 'What is your current total compensation (salary, bonuses, and perks, before taxes and deductions)? Please enter a whole number in the box below, without any punctuation.  If you are paid hourly, please estimate an equivalent weekly, monthly, or yearly salary. If you prefer not to answer, please leave the box empty.'

# %%
high_salary = (df['ConvertedCompYearly'] > 100_000)

# %%
df.loc[high_salary, ['ResponseId', 'Country', 'LanguageHaveWorkedWith', 'Ethnicity', 'ConvertedCompYearly']]
# Out:
#        ResponseId                                               Country  \
# 3               4                                                Israel
# 11             12                              United States of America
# 14             15                              United States of America
# 17             18                                               Austria
# 26             27                              United States of America
# ...           ...                                                   ...
# 73101       73102                                           Switzerland
# 73102       73103  United Kingdom of Great Britain and Northern Ireland
# 73105       73106                              United States of America
# 73111       73112                              United States of America
# 73116       73117                              United States of America
#
#                                                                LanguageHaveWorkedWith  \
# ...

# %%
high_salary_df = df.loc[high_salary, ['ResponseId', 'Country', 'LanguageHaveWorkedWith', 'Ethnicity', 'ConvertedCompYearly']]

# %%
high_salary_df.to_csv('high_earners.csv')

# %%
df['ConvertedCompYearly'].median()
# Out:
# 67845.0

# %%
df['ConvertedCompYearly'].mean()
# Out:
# 170761.2778492816

# %%
df['ConvertedCompYearly'].mode()
# Out:
# 0    150000.0
# Name: ConvertedCompYearly, dtype: float64

# %%
df.median()
# Out:
# C:\Users\jimio\AppData\Local\Temp\ipykernel_9516\530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# ResponseId                   36634.5
# CompTotal                    77500.0
# VCHostingPersonal use            NaN
# VCHostingProfessional use        NaN
# WorkExp                          8.0
# ConvertedCompYearly          67845.0
# dtype: float64

# %%
df['Country'].value_counts()
# Out:
# United States of America                                13543
# India                                                    6639
# Germany                                                  5395
# United Kingdom of Great Britain and Northern Ireland     4190
# Canada                                                   2490
#                                                         ...
# Monaco                                                      1
# Djibouti                                                    1
# Seychelles                                                  1
# Solomon Islands                                             1
# Saint Kitts and Nevis                                       1
# Name: Country, Length: 180, dtype: int64

# %%
df.groupby(['Country'])

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('United Kingdom of Great Britain and Northern Ireland')
# Out:
#        ResponseId  \
# 2               3
# 10             11
# 77             78
# 84             85
# 94             95
# ...           ...
# 73129       73130
# 73177       73178
# 73245       73246
# 73248       73249
# 73266       73267
#
#                                                                           MainBranch  \
# 2      I am not primarily a developer, but I write code sometimes as part of my work
# 10                                                    I am a developer by profession
# 77                          I used to be a developer by profession, but no longer am
# 84                                                    I am a developer by profession
# 94                                                    I am a developer by profession
# ...                                                                              ...
# 73129                                                          I am learning to code
# ...

# %%
uk_data = country_grp.get_group('United Kingdom of Great Britain and Northern Ireland')

# %%
uk_data.to_csv('uk_data.csv')

# %%
uk_data.to_csv('C:/Users/jimio/Documents/uk_data.csv')

# %%
country_grp.get_group('Nigeria')
# Out:
#        ResponseId                      MainBranch  \
# 4391         4392  I am a developer by profession
# 4600         4601  I am a developer by profession
# 5760         5761  I am a developer by profession
# 6410         6411  I am a developer by profession
# 6598         6599  I am a developer by profession
# ...           ...                             ...
# 72980       72981  I am a developer by profession
# 73118       73119  I am a developer by profession
# 73134       73135  I am a developer by profession
# 73155       73156     I code primarily as a hobby
# 73263       73264  I am a developer by profession
#
#                                    Employment  \
# 4391                      Employed, full-time
# 4600                      Employed, full-time
# 5760                      Employed, full-time
# 6410                       Student, part-time
# 6598   Student, part-time;Employed, part-time
# ...                                       ...
# ...

# %%
country_grp['ConvertedCompYearly'].median()
# Out:
# Country
# Afghanistan                             10894.0
# Albania                                 15360.0
# Algeria                                  7440.0
# Andorra                                 76784.0
# Angola                                   3073.5
#                                          ...
# Venezuela, Bolivarian Republic of...    12000.0
# Viet Nam                                11388.0
# Yemen                                   15000.0
# Zambia                                   6612.0
# Zimbabwe                                11400.0
# Name: ConvertedCompYearly, Length: 180, dtype: float64

# %%
country_grp['ConvertedCompYearly'].median().loc['Nigeria']
# Out:
# 14436.0

# %%
country_grp['ConvertedCompYearly'].median().loc['United Kingdom of Great Britain and Northern Ireland']
# Out:
# 82922.0

# %%
country_grp['ConvertedCompYearly'].median().loc['United States of America']
# Out:
# 145000.0

# %%
country_grp['ConvertedCompYearly'].median().loc['Canada']
# Out:
# 93701.0

# %%
country_grp['ConvertedCompYearly'].median().loc['Germany']
# Out:
# 69318.0

# %%
df.drop(columns = [ 'VersionControlSystem', 'VCInteraction', 
       'Blockchain',  'NEWSOSites',
       'SOVisitFreq', 'SOAccount', 'SOPartFreq', 'SOComm',  'Trans', 'Sexuality', 'Accessibility',
       'MentalHealth',  'TBranch', 'ICorPM', 
       'TimeSearching', 'TimeAnswering', 'Onboarding',
       'ProfessionalTech',  'SurveyLength',
       'SurveyEase', 'Knowledge_1', 'Knowledge_2', 'Knowledge_3',
       'Knowledge_4', 'Knowledge_5', 'Knowledge_6', 'Knowledge_7',
       'Frequency_1', 'Frequency_2', 'Frequency_3', 'TrueFalse_1',
       'TrueFalse_2', 'TrueFalse_3'], inplace = True)
     #Dropping columns I will not be using for the Tableau visualisation

# %%
df.to_csv('C:/Users/jimio/Documents/dropped_columns.csv')
